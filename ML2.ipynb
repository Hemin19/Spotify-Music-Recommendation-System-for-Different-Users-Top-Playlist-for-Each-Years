# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import LabelEncoder

# %%
df_alpha_2016 = pd.read_csv("data/recovered_data/user_alpha/user_alpha_2016.csv")
df_alpha_2017 = pd.read_csv("data/recovered_data/user_alpha/user_alpha_2017.csv")
df_alpha_2018 = pd.read_csv("data/recovered_data/user_alpha/user_alpha_2018.csv")
df_alpha_2019 = pd.read_csv("data/recovered_data/user_alpha/user_alpha_2019.csv")
df_alpha_2020 = pd.read_csv("data/recovered_data/user_alpha/user_alpha_2020.csv")
df_alpha_2021 = pd.read_csv("data/recovered_data/user_alpha/user_alpha_2021.csv")
df_alpha_2022 = pd.read_csv("data/recovered_data/user_alpha/user_alpha_2022.csv")

# %%
df_beta_2016 = pd.read_csv("data/recovered_data/user_beta/user_beta_2016.csv")
df_beta_2017 = pd.read_csv("data/recovered_data/user_beta/user_beta_2017.csv")
df_beta_2018 = pd.read_csv("data/recovered_data/user_beta/user_beta_2018.csv")
df_beta_2019 = pd.read_csv("data/recovered_data/user_beta/user_beta_2019.csv")
df_beta_2020 = pd.read_csv("data/recovered_data/user_beta/user_beta_2020.csv")
df_beta_2021 = pd.read_csv("data/recovered_data/user_beta/user_beta_2021.csv")
df_beta_2022 = pd.read_csv("data/recovered_data/user_beta/user_beta_2022.csv")

# %%
df_delta_2016 = pd.read_csv("data/recovered_data/user_delta/user_delta_2016.csv")
df_delta_2017 = pd.read_csv("data/recovered_data/user_delta/user_delta_2017.csv")
df_delta_2018 = pd.read_csv("data/recovered_data/user_delta/user_delta_2018.csv")
df_delta_2019 = pd.read_csv("data/recovered_data/user_delta/user_delta_2019.csv")
df_delta_2020 = pd.read_csv("data/recovered_data/user_delta/user_delta_2020.csv")
df_delta_2021 = pd.read_csv("data/recovered_data/user_delta/user_delta_2021.csv")
df_delta_2022 = pd.read_csv("data/recovered_data/user_delta/user_delta_2022.csv")

# %%
df_epsilon_2016 = pd.read_csv("data/recovered_data/user_epsilon/user_epsilon_2016.csv")
df_epsilon_2017 = pd.read_csv("data/recovered_data/user_epsilon/user_epsilon_2017.csv")
df_epsilon_2018 = pd.read_csv("data/recovered_data/user_epsilon/user_epsilon_2018.csv")
df_epsilon_2019 = pd.read_csv("data/recovered_data/user_epsilon/user_epsilon_2019.csv")
df_epsilon_2020 = pd.read_csv("data/recovered_data/user_epsilon/user_epsilon_2020.csv")
df_epsilon_2021 = pd.read_csv("data/recovered_data/user_epsilon/user_epsilon_2021.csv")
df_epsilon_2022 = pd.read_csv("data/recovered_data/user_epsilon/user_epsilon_2022.csv")

# %%
df_gamma_2016 = pd.read_csv("data/recovered_data/user_gamma/user_gamma_2016.csv")
df_gamma_2017 = pd.read_csv("data/recovered_data/user_gamma/user_gamma_2017.csv")
df_gamma_2018 = pd.read_csv("data/recovered_data/user_gamma/user_gamma_2018.csv")
df_gamma_2019 = pd.read_csv("data/recovered_data/user_gamma/user_gamma_2019.csv")
df_gamma_2020 = pd.read_csv("data/recovered_data/user_gamma/user_gamma_2020.csv")
df_gamma_2021 = pd.read_csv("data/recovered_data/user_gamma/user_gamma_2021.csv")
df_gamma_2022 = pd.read_csv("data/recovered_data/user_gamma/user_gamma_2022.csv")

# %%
df_zeta_2020 = pd.read_csv("data/recovered_data/user_zeta/user_zeta_2020.csv")
df_zeta_2021 = pd.read_csv("data/recovered_data/user_zeta/user_zeta_2021.csv")
df_zeta_2022 = pd.read_csv("data/recovered_data/user_zeta/user_zeta_2022.csv")

# %%
df_zeta_2020.info()
df_zeta_2021.info()
df_zeta_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              100 non-null    object
#  1   album             100 non-null    object
#  2   artist            100 non-null    object
#  3   release_date      100 non-null    object
#  4   length            100 non-null    int64
#  5   popularity        100 non-null    int64
#  6   acousticness      100 non-null    float64
#  7   danceability      100 non-null    float64
#  8   energy            100 non-null    float64
#  9   instrumentalness  100 non-null    float64
#  10  liveness          100 non-null    float64
#  11  loudness          100 non-null    float64
#  12  speechiness       100 non-null    float64
#  13  tempo             100 non-null    float64
#  14  valence           100 non-null    float64
#  15  time_signature    100 non-null    int64
# ...

# %%
df_gamma_2016.info()
df_gamma_2017.info()
df_gamma_2018.info()
df_gamma_2019.info()
df_gamma_2020.info()
df_gamma_2021.info()
df_gamma_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              100 non-null    object
#  1   album             100 non-null    object
#  2   artist            100 non-null    object
#  3   release_date      100 non-null    object
#  4   length            100 non-null    int64
#  5   popularity        100 non-null    int64
#  6   acousticness      100 non-null    float64
#  7   danceability      100 non-null    float64
#  8   energy            100 non-null    float64
#  9   instrumentalness  100 non-null    float64
#  10  liveness          100 non-null    float64
#  11  loudness          100 non-null    float64
#  12  speechiness       100 non-null    float64
#  13  tempo             100 non-null    float64
#  14  valence           100 non-null    float64
#  15  time_signature    100 non-null    int64
# ...

# %%
df_epsilon_2016.info()
df_epsilon_2017.info()
df_epsilon_2018.info()
df_epsilon_2019.info()
df_epsilon_2020.info()
df_epsilon_2021.info()
df_epsilon_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              100 non-null    object
#  1   album             100 non-null    object
#  2   artist            100 non-null    object
#  3   release_date      100 non-null    object
#  4   length            100 non-null    int64
#  5   popularity        100 non-null    int64
#  6   acousticness      100 non-null    float64
#  7   danceability      100 non-null    float64
#  8   energy            100 non-null    float64
#  9   instrumentalness  100 non-null    float64
#  10  liveness          100 non-null    float64
#  11  loudness          100 non-null    float64
#  12  speechiness       100 non-null    float64
#  13  tempo             100 non-null    float64
#  14  valence           100 non-null    float64
#  15  time_signature    100 non-null    int64
# ...

# %%
df_delta_2016.info()
df_delta_2017.info()
df_delta_2018.info()
df_delta_2019.info()
df_delta_2020.info()
df_delta_2021.info()
df_delta_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              100 non-null    object
#  1   album             100 non-null    object
#  2   artist            100 non-null    object
#  3   release_date      100 non-null    object
#  4   length            100 non-null    int64
#  5   popularity        100 non-null    int64
#  6   acousticness      100 non-null    float64
#  7   danceability      100 non-null    float64
#  8   energy            100 non-null    float64
#  9   instrumentalness  100 non-null    float64
#  10  liveness          100 non-null    float64
#  11  loudness          100 non-null    float64
#  12  speechiness       100 non-null    float64
#  13  tempo             100 non-null    float64
#  14  valence           100 non-null    float64
#  15  time_signature    100 non-null    int64
# ...

# %%
df_beta_2016.info()
df_beta_2017.info()
df_beta_2018.info()
df_beta_2019.info()
df_beta_2020.info()
df_beta_2021.info()
df_beta_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              100 non-null    object
#  1   album             100 non-null    object
#  2   artist            100 non-null    object
#  3   release_date      100 non-null    object
#  4   length            100 non-null    int64
#  5   popularity        100 non-null    int64
#  6   acousticness      100 non-null    float64
#  7   danceability      100 non-null    float64
#  8   energy            100 non-null    float64
#  9   instrumentalness  100 non-null    float64
#  10  liveness          100 non-null    float64
#  11  loudness          100 non-null    float64
#  12  speechiness       100 non-null    float64
#  13  tempo             100 non-null    float64
#  14  valence           100 non-null    float64
#  15  time_signature    100 non-null    int64
# ...

# %%
df_alpha_2016.info()
df_alpha_2017.info()
df_alpha_2018.info()
df_alpha_2019.info()
df_alpha_2020.info()
df_alpha_2021.info()
df_alpha_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              100 non-null    object
#  1   album             100 non-null    object
#  2   artist            100 non-null    object
#  3   release_date      100 non-null    object
#  4   length            100 non-null    int64
#  5   popularity        100 non-null    int64
#  6   acousticness      100 non-null    float64
#  7   danceability      100 non-null    float64
#  8   energy            100 non-null    float64
#  9   instrumentalness  100 non-null    float64
#  10  liveness          100 non-null    float64
#  11  loudness          100 non-null    float64
#  12  speechiness       100 non-null    float64
#  13  tempo             100 non-null    float64
#  14  valence           100 non-null    float64
#  15  time_signature    100 non-null    int64
# ...

# %%
alpha_df = pd.concat([df_alpha_2016, df_alpha_2017, df_alpha_2018, df_alpha_2019, df_alpha_2020, df_alpha_2021, df_alpha_2022], ignore_index=True, axis=0)
beta_df = pd.concat([df_beta_2016, df_beta_2017, df_beta_2018, df_beta_2019, df_beta_2020, df_beta_2021, df_beta_2022], ignore_index=True, axis=0)
delta_df = pd.concat([df_delta_2016, df_delta_2017, df_delta_2018, df_delta_2019, df_delta_2020, df_delta_2021, df_delta_2022], ignore_index=True, axis=0)
epsilon_df = pd.concat([df_epsilon_2016, df_epsilon_2017, df_epsilon_2018, df_epsilon_2019, df_epsilon_2020, df_epsilon_2021, df_epsilon_2022], ignore_index=True, axis=0)
gamma_df = pd.concat([df_gamma_2016, df_gamma_2017, df_gamma_2018, df_gamma_2019, df_gamma_2020, df_gamma_2021, df_gamma_2022], ignore_index=True, axis=0)
zeta_df = pd.concat([df_zeta_2020, df_zeta_2021, df_zeta_2022], ignore_index=True, axis=0)

# %%
#Visualising the dataset with histograms
# Select numerical columns for plotting
numerical_columns = ['length', 'popularity', 'acousticness', 'danceability', 'energy', 'instrumentalness',
                      'liveness', 'loudness', 'speechiness', 'tempo', 'valence']

# Calculate the number of rows and columns for subplots
num_cols = 4
num_rows = -(-len(numerical_columns) // num_cols)  # Ceiling division to ensure enough rows

# Set up subplots
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(16, 3 * num_rows))
fig.subplots_adjust(hspace=0.5)

# Flatten the axes for easier iteration
axes = axes.flatten()

# Plot each numerical feature
for i, column in enumerate(numerical_columns):
    sns.histplot(alpha_df[column], ax=axes[i], kde=True)
    axes[i].set_title(f'Distribution of {column}')
    axes[i].set_xlabel(column)
    axes[i].set_ylabel('Frequency')

# Hide any remaining empty subplots
for j in range(len(numerical_columns), len(axes)):
    axes[j].axis('off')

# Show the plots
plt.show()

# %%
plt.figure(figsize=(20, 6))
sns.countplot(x='release_year', data=alpha_df)
plt.title('Number of Releases by Year')
plt.xlabel('Release Year')
plt.ylabel('Count')
plt.show()

# %%
mixed_playlist = pd.concat([alpha_df, beta_df, delta_df, epsilon_df, gamma_df, zeta_df], ignore_index=True, axis=0)

# %%
mixed_playlist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3799 entries, 0 to 3798
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              3790 non-null   object
#  1   album             3790 non-null   object
#  2   artist            3799 non-null   object
#  3   release_date      3799 non-null   object
#  4   length            3799 non-null   int64
#  5   popularity        3799 non-null   int64
#  6   acousticness      3799 non-null   float64
#  7   danceability      3799 non-null   float64
#  8   energy            3799 non-null   float64
#  9   instrumentalness  3799 non-null   float64
#  10  liveness          3799 non-null   float64
#  11  loudness          3799 non-null   float64
#  12  speechiness       3799 non-null   float64
#  13  tempo             3799 non-null   float64
#  14  valence           3799 non-null   float64
#  15  time_signature    3799 non-null   int64
# ...

# %%
mixed_playlist.head()
# Out:
#                      name                    album              artist  \
# 0          Petit bonhomme  Tant Pis ! Tant Mieux !        Les Wriggles
# 1  Bei Mir Bist Du Schoen         Wake Up In Paris    The Hot Sardines
# 2    Les gens qui doutent          Favourite Songs      Vincent Delerm
# 3             Les saintes           Jusqu'à la mer  Amélie-Les-Crayons
# 4  Les moutons - Cuvée 97                Antaology            Matmatah
#
#   release_date  length  popularity  acousticness  danceability  energy  \
# 0   2007-11-19  203746           1         0.863         0.827   0.190
# 1   2014-10-20  246440          18         0.613         0.725   0.454
# 2   2007-10-29  216400           0         0.922         0.383   0.526
# 3   2012-10-08  141000          21         0.897         0.858   0.392
# 4   2015-09-25  229560          16         0.500         0.607   0.951
#
#    instrumentalness  ...  speechiness    tempo  valence  time_signature  key  \
# ...

# %%
mixed_playlist.drop_duplicates(subset=['user','name'])
# Out:
#                         name                    album              artist  \
# 0             Petit bonhomme  Tant Pis ! Tant Mieux !        Les Wriggles
# 1     Bei Mir Bist Du Schoen         Wake Up In Paris    The Hot Sardines
# 2       Les gens qui doutent          Favourite Songs      Vincent Delerm
# 3                Les saintes           Jusqu'à la mer  Amélie-Les-Crayons
# 4     Les moutons - Cuvée 97                Antaology            Matmatah
# ...                      ...                      ...                 ...
# 3794         The Masked Ball                Boundless   Pomegranate Tiger
# 3795                Le milli                 ZZCCMXTP          KronoMuzik
# 3796             Salma Hayek              Salma Hayek        WARGASM (UK)
# 3797               Lezgongue                 ZZCCMXTP          KronoMuzik
# 3798        The Water's Fine     The Stuff of Legends     Challenger Deep
#
#      release_date  length  popularity  acousticness  danceability  energy  \
# ...

# %%
mixed_playlist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3799 entries, 0 to 3798
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              3790 non-null   object
#  1   album             3790 non-null   object
#  2   artist            3799 non-null   object
#  3   release_date      3799 non-null   object
#  4   length            3799 non-null   int64
#  5   popularity        3799 non-null   int64
#  6   acousticness      3799 non-null   float64
#  7   danceability      3799 non-null   float64
#  8   energy            3799 non-null   float64
#  9   instrumentalness  3799 non-null   float64
#  10  liveness          3799 non-null   float64
#  11  loudness          3799 non-null   float64
#  12  speechiness       3799 non-null   float64
#  13  tempo             3799 non-null   float64
#  14  valence           3799 non-null   float64
#  15  time_signature    3799 non-null   int64
# ...

# %%
le = LabelEncoder()

# %%
mixed_playlist[['artist']].value_counts()
# Out:
# artist
# Various Artists    124
# Gaël Faye           71
# Leonard Cohen       49
# Sofiane Pamart      39
# Sexion d'Assaut     36
#                   ...
# Danheim              1
# Limousine            1
# Lior Shoov           1
# Liquid Cinema        1
# Bonga                1
# Name: count, Length: 1393, dtype: int64

# %%
mixed_playlist[['user']].value_counts()
# Out:
# user
# alpha      700
# beta       700
# delta      700
# gamma      700
# epsilon    699
# zeta       300
# Name: count, dtype: int64

# %%
mixed_playlist['user'] = le.fit_transform(mixed_playlist['user'])

# %%
mixed_playlist['artist'] = le.fit_transform(mixed_playlist['artist'])

# %%
mixed_playlist['top_year'] = le.fit_transform(mixed_playlist['top_year'])

# %%
X = mixed_playlist[['artist','length','popularity','energy','instrumentalness','liveness','loudness','speechiness','valence']]
y = mixed_playlist['user']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay,classification_report,roc_curve,auc,roc_auc_score 
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV, RepeatedStratifiedKFold

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.7,shuffle=True,random_state=42)

# %%
rf = RandomForestClassifier(random_state=42)

# %%
dt=DecisionTreeClassifier(random_state=42)

# %%
space = dict()

space['criterion'] = ['gini', 'entropy']
space['n_estimators'] = [1,10,100,300]
space['max_depth'] = [1,5,15,20,25,30]
space['max_features'] = ['sqrt', 'log2']

search = GridSearchCV(rf, space, scoring='accuracy')

# execute search
result = search.fit(X=X_train, y=y_train)
# summarize result
print('Best Score: %s' % result.best_score_)
print('Best Hyperparameters: %s' % result.best_params_)
# Out:
# Best Score: 0.5565870891919064
# Best Hyperparameters: {'criterion': 'entropy', 'max_depth': 15, 'max_features': 'sqrt', 'n_estimators': 300}

# %%
X = mixed_playlist[['artist','length','popularity','energy','instrumentalness','liveness','loudness','speechiness','valence']]
y = mixed_playlist['top_year']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.7,shuffle=True,random_state=42)

# %%
space = dict()

space['criterion'] = ['gini', 'entropy']
space['n_estimators'] = [1,10,100,300]
space['max_depth'] = [1,5,15,20,25,30]
space['max_features'] = ['sqrt', 'log2']

search = GridSearchCV(rf, space, scoring='accuracy')

# execute search
result = search.fit(X=X_train, y=y_train)
# summarize result
print('Best Score: %s' % result.best_score_)
print('Best Hyperparameters: %s' % result.best_params_)
# Out:
# Best Score: 0.2767936791130368
# Best Hyperparameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 300}

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, shuffle=True, random_state=42)
# Out:
# (2659, 9) (2659,)
# (3799, 9) (1140,)

# %%
# Assuming 'search' is your GridSearchCV instance

# Extract the best hyperparameters from the search results
best_params = result.best_params_

# Create a new RandomForestClassifier instance with the best hyperparameters
best_rf = RandomForestClassifier(
    criterion=best_params['criterion'],
    n_estimators=best_params['n_estimators'],
    max_depth=best_params['max_depth'],
    max_features=best_params['max_features'],
    random_state=42  # You may want to set a random state for reproducibility
)

# Fit the model on the entire training dataset
best_rf.fit(X_train, y_train)

# Now, you can use the trained model to make predictions on the test set
y_pred = best_rf.predict(X_test)

# If you want predicted probabilities, you can use predict_proba
y_pred_proba = best_rf.predict_proba(X_test)

# %%
# Assuming 'best_rf' is your trained RandomForestClassifier
# Assuming 'X_test' is the new data on which you want to make predictions

# Make predictions on new data
new_data_predictions = best_rf.predict(X_test)

# If you want predicted probabilities, you can use predict_proba
new_data_probabilities = best_rf.predict_proba(X_test)

# Create a DataFrame with the predictions and the corresponding features if needed
predictions_df = pd.DataFrame({'Prediction': new_data_predictions})

# Assuming 'X_test' is the DataFrame representing your new data
# Add the features from 'X_test' to the predictions DataFrame if needed
predictions_df = pd.concat([X_test, predictions_df], axis=1)

# Specify the path where you want to save the CSV file
output_path = 'data/predictions.csv'  # Replace with your desired path

# Save the DataFrame to a CSV file
predictions_df.to_csv(output_path, index=False)

print(f'Predictions saved to: {output_path}')
# Out:
# Predictions saved to: data/predictions.csv
